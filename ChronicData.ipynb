# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('kidney_disease.csv')
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 25)

# %%
df.columns=[
    "Age",
    "Blood Pressure",
    "Specific Gravity",
    "Albumin",
    "Sugar",
    "Red Blood Cells",
    "Pus Cell",
    "Pus Cell Clumps",
    "Bacteria",
    "Blood Glucose Random",
    "Blood Urea",
    "Serum Creatinine",
    "Sodium",
    "Potassium",
    "Hemoglobin",
    "Packed Cell Volume",
    "White Blood Cell Count",
    "Red Blood Cell Count",
    "Hypertension",
    "Diabetes Mellitus",
    "Coronary Artery Disease",
    "Appetite",
    "Pedal Edema",
    "Anemia",
    "Classification"
]

# %%
df.head()
# Out:
#     Age  Blood Pressure  Specific Gravity  Albumin  Sugar Red Blood Cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    Pus Cell Pus Cell Clumps    Bacteria  Blood Glucose Random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    Packed Cell Volume  White Blood Cell Count  Red Blood Cell Count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      391 non-null    float64
#  1   Blood Pressure           388 non-null    float64
#  2   Specific Gravity         353 non-null    float64
#  3   Albumin                  354 non-null    float64
#  4   Sugar                    351 non-null    float64
#  5   Red Blood Cells          248 non-null    object
#  6   Pus Cell                 335 non-null    object
#  7   Pus Cell Clumps          396 non-null    object
#  8   Bacteria                 396 non-null    object
#  9   Blood Glucose Random     356 non-null    float64
#  10  Blood Urea               381 non-null    float64
#  11  Serum Creatinine         383 non-null    float64
#  12  Sodium                   313 non-null    float64
#  13  Potassium                312 non-null    float64
# ...

# %%
df['Packed Cell Volume'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df['Packed Cell Volume']=pd.to_numeric(df['Packed Cell Volume'], errors= 'coerce') #coerce means just ignore the errors
df['Packed Cell Volume'].size
# Out:
# 400

# %%
df['White Blood Cell Count'].unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
df['White Blood Cell Count']=pd.to_numeric(df['White Blood Cell Count'], errors= 'coerce')
df['Red Blood Cell Count']=pd.to_numeric(df['Red Blood Cell Count'], errors= 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      391 non-null    float64
#  1   Blood Pressure           388 non-null    float64
#  2   Specific Gravity         353 non-null    float64
#  3   Albumin                  354 non-null    float64
#  4   Sugar                    351 non-null    float64
#  5   Red Blood Cells          248 non-null    object
#  6   Pus Cell                 335 non-null    object
#  7   Pus Cell Clumps          396 non-null    object
#  8   Bacteria                 396 non-null    object
#  9   Blood Glucose Random     356 non-null    float64
#  10  Blood Urea               381 non-null    float64
#  11  Serum Creatinine         383 non-null    float64
#  12  Sodium                   313 non-null    float64
#  13  Potassium                312 non-null    float64
# ...

# %%
# separating numerical and categorical column
catcol=[col for col in df.columns if df[col].dtype =='object']
numcol=[col for col in df.columns if df[col].dtype !='object']

# %%
numcol
# Out:
# ['Age',
#  'Blood Pressure',
#  'Specific Gravity',
#  'Albumin',
#  'Sugar',
#  'Blood Glucose Random',
#  'Blood Urea',
#  'Serum Creatinine',
#  'Sodium',
#  'Potassium',
#  'Hemoglobin',
#  'Packed Cell Volume',
#  'White Blood Cell Count',
#  'Red Blood Cell Count']

# %%
for col in catcol:
    print(f"{col} has {df[col].unique()} values.")
# Out:
# Red Blood Cells has [nan 'normal' 'abnormal'] values.
# Pus Cell has ['normal' 'abnormal' nan] values.
# Pus Cell Clumps has ['notpresent' 'present' nan] values.
# Bacteria has ['notpresent' 'present' nan] values.
# Hypertension has ['yes' 'no' nan] values.
# Diabetes Mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values.
# Coronary Artery Disease has ['no' 'yes' '\tno' nan] values.
# Appetite has ['good' 'poor' nan] values.
# Pedal Edema has ['no' 'yes' nan] values.
# Anemia has ['no' 'yes' nan] values.
# Classification has ['ckd' 'ckd\t' 'notckd'] values.

# %%
df['Diabetes Mellitus'].replace(to_replace={' yes':'yes','\tyes':'yes', '\tno':'no'}, inplace =True)
df['Coronary Artery Disease'].replace(to_replace={'\tno':'no'}, inplace =True)
df['Classification'].replace(to_replace={'ckd\t':'ckd'}, inplace =True)

# %%
for col in catcol:
    print(f"{col} has {df[col].unique()} values.")
# Out:
# Red Blood Cells has [nan 'normal' 'abnormal'] values.
# Pus Cell has ['normal' 'abnormal' nan] values.
# Pus Cell Clumps has ['notpresent' 'present' nan] values.
# Bacteria has ['notpresent' 'present' nan] values.
# Hypertension has ['yes' 'no' nan] values.
# Diabetes Mellitus has ['yes' 'no' nan] values.
# Coronary Artery Disease has ['no' 'yes' nan] values.
# Appetite has ['good' 'poor' nan] values.
# Pedal Edema has ['no' 'yes' nan] values.
# Anemia has ['no' 'yes' nan] values.
# Classification has ['ckd' 'notckd'] values.

# %%
# Univariate analysis

plt.figure(figsize=(10,6))
sns.histplot(df['Age'].dropna(), kde=True, bins=20, color='b')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
# insight : age is left skewed data

# %%
sns.countplot(x='Hypertension',data=df, palette='viridis')
# sns.countplot(x='Hypertension',data=df, color='blue',  palette='viridis')
# Out:
# <Axes: xlabel='Hypertension', ylabel='count'>

# %%
sns.boxplot(x='Classification',y='Hemoglobin',data=df,palette='viridis')
# Out:
# <Axes: xlabel='Classification', ylabel='Hemoglobin'>

# %%
# insights: People with kidney disease have lower hemoglobin with outlier

# %%
sns.violinplot(x='Classification',y='Hemoglobin',data=df, palette='muted')
# Out:
# <Axes: xlabel='Classification', ylabel='Hemoglobin'>

# %%
sns.countplot(x='Anemia',data=df, palette='pastel')
# Out:
# <Axes: xlabel='Anemia', ylabel='count'>

# %%
# insights: majority of people not suffering from aanemia

# %%
df.Appetite.value_counts().plot.pie(autopct='%1.1f%%',colors=['green','maroon'], explode=(0, 0.15), shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df['White Blood Cell Count'].dropna())
sns.histplot(x='White Blood Cell Count', data=df, color='skyblue')
# Out:
# <Axes: xlabel='White Blood Cell Count', ylabel='Count'>

# %%
df['Diabetes Mellitus'].value_counts().plot.pie(autopct='%1.1f%%',title='Diabetes Donut chart', wedgeprops=dict(width=0.5))
# here wedgeprops makes piechart to donut chart
# Out:
# <Axes: title={'center': 'Diabetes Donut chart'}, ylabel='count'>

# %%
data = pd.Series([40, 35, 25], index=['a', 'b', 'c'])
data.plot.pie(autopct='%1.1f%%', colors=['r','g','b'])
# Out:
# <Axes: >
